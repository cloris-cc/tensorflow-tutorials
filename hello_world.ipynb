# %% [markdown]
# ### 照片分类器

# %%
# 导入 tensorflow

import tensorflow as tf

print(tf.__version__)
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# 2.5.0

# %% [markdown]
# #### 1. 加载和预处理数据 (mnist 的 28x28 灰度图像数据集)

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# tired

# %% [markdown]
# #### 2. 使用 Keras 构建和训练模型

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)

model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 2021-07-29 05:20:01.151147: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-07-29 05:20:01.151578: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-07-29 05:20:01.435170: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-07-29 05:20:01.440500: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-07-29 05:20:01.562578: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2021-07-29 05:20:47.473519: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Metal device set to: Apple M1
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2994 - accuracy: 0.9131
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1435 - accuracy: 0.9580
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1075 - accuracy: 0.9683
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0893 - accuracy: 0.9721
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0749 - accuracy: 0.9768
# 313/313 - 1s - loss: 0.0681 - accuracy: 0.9784
# finished
