# %% [markdown]
# ### 使用 tf.data 加载 pandas dataframes

# %%
import pandas as pd
import tensorflow as tf
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
csv_file = tf.keras.utils.get_file('heart.csv', 'https://storage.googleapis.com/applied-dl/heart.csv')
df = pd.read_csv(csv_file)

df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal         object
# target        int64
# dtype: object

# %%
# 将 thal 列（dtype: object）转换为离散数值。
df['thal'] = pd.Categorical(df['thal'])
df['thal'] = df.thal.cat.codes

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  target
# 0   0     2       0
# 1   3     3       1
# 2   2     4       0
# 3   0     3       0
# 4   0     3       0

# %%
target = df.pop('target')

# %%
# (x, y) / (features, labels) 格式。使用的是数值values
dataset = tf.data.Dataset.from_tensor_slices((df.values, target.values))
train_dataset = dataset.shuffle(len(df)).batch(1)
# Out:
# Metal device set to: Apple M1
# 2021-08-29 10:18:43.884751: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-08-29 10:18:43.885025: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model


model = build_model()

model.fit(train_dataset, epochs=15)
# Out:
# Epoch 1/15
# 2021-08-29 10:18:44.082037: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-08-29 10:18:44.084344: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-08-29 10:18:44.084750: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 303/303 [==============================] - 2s 7ms/step - loss: 4.3999 - accuracy: 0.4884
# Epoch 2/15
# 303/303 [==============================] - 2s 7ms/step - loss: 0.6530 - accuracy: 0.7228
# Epoch 3/15
# 303/303 [==============================] - 2s 7ms/step - loss: 0.6369 - accuracy: 0.7228
# Epoch 4/15
# 303/303 [==============================] - 2s 7ms/step - loss: 0.6249 - accuracy: 0.7261
# Epoch 5/15
# 303/303 [==============================] - 2s 6ms/step - loss: 0.6159 - accuracy: 0.7261
# Epoch 6/15
# 303/303 [==============================] - 2s 6ms/step - loss: 0.6088 - accuracy: 0.7261
# Epoch 7/15
# 303/303 [==============================] - 2s 7ms/step - loss: 0.6035 - accuracy: 0.7261
# Epoch 8/15
# 303/303 [==============================] - 2s 6ms/step - loss: 0.5995 - accuracy: 0.7261
# Epoch 9/15
# 303/303 [==============================] - 2s 6ms/step - loss: 0.5965 - accuracy: 0.7261
# Epoch 10/15
# 303/303 [==============================] - 2s 6ms/step - loss: 0.5942 - accuracy: 0.7261
# Epoch 11/15
# 303/303 [==============================] - 2s 6ms/step - loss: 0.5925 - accuracy: 0.7261
# Epoch 12/15
# 303/303 [==============================] - 2s 6ms/step - loss: 0.5912 - accuracy: 0.7261
# Epoch 13/15
# 303/303 [==============================] - 2s 6ms/step - loss: 0.5903 - accuracy: 0.7261
# Epoch 14/15
# 303/303 [==============================] - 2s 7ms/step - loss: 0.5895 - accuracy: 0.7261
# Epoch 15/15
# 303/303 [==============================] - 2s 7ms/step - loss: 0.5891 - accuracy: 0.7261

# %%
inputs = {key: tf.keras.layers.Input(shape=(), name=key) for key in df.keys()}
x = tf.stack(list(inputs.values()), axis=-1)

x = tf.keras.layers.Dense(10, activation='relu')(x)
output = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model_func = tf.keras.Model(inputs=inputs, outputs=output)

model_func.compile(optimizer='adam',
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

# %%
dict_slices = tf.data.Dataset.from_tensor_slices((df.to_dict('list'), target.values)).batch(16)

# %%
model_func.fit(dict_slices, epochs=15)
# Out:
# Epoch 1/15
#  5/19 [======>.......................] - ETA: 0s - loss: 6.4591 - accuracy: 0.7500
# 2021-08-29 10:33:09.407598: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 19/19 [==============================] - 0s 13ms/step - loss: 5.4714 - accuracy: 0.7261
# Epoch 2/15
# 19/19 [==============================] - 0s 11ms/step - loss: 1.3546 - accuracy: 0.6799
# Epoch 3/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.7940 - accuracy: 0.7228
# Epoch 4/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.7073 - accuracy: 0.7129
# Epoch 5/15
# 19/19 [==============================] - 0s 12ms/step - loss: 0.6663 - accuracy: 0.7228
# Epoch 6/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6668 - accuracy: 0.7162
# Epoch 7/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6557 - accuracy: 0.7195
# Epoch 8/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6443 - accuracy: 0.7228
# Epoch 9/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6353 - accuracy: 0.7228
# Epoch 10/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6261 - accuracy: 0.7228
# Epoch 11/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6173 - accuracy: 0.7327
# Epoch 12/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6090 - accuracy: 0.7360
# Epoch 13/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.6011 - accuracy: 0.7393
# Epoch 14/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.5935 - accuracy: 0.7360
# Epoch 15/15
# 19/19 [==============================] - 0s 11ms/step - loss: 0.5862 - accuracy: 0.7393
