# %% [markdown]
# ### 使用 tf.data.Dataset 加载 NumPy 数组
#
# numpy to ds
#
# tf.data.Dataset.from_tensor_slices((train_features, train_labels))

# %%
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
DATA_URL = 'https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz'
path = tf.keras.utils.get_file('mnist.npz', DATA_URL)

with np.load(path) as data:
    train_features = data['x_train']
    train_labels = data['y_train']
    test_features = data['x_test']
    test_labels = data['y_test']

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_features, test_labels))

# %%
# 优化dataset
BATCH_SIZE = 64
SHUFFLE_BUFFER_SIZE = 100

# todo .cache .prefetch
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.RMSprop(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.fit(train_dataset, epochs=10)
# Out:
# Epoch 1/10
# 2021-08-22 05:21:01.259693: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-08-22 05:21:01.262231: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2021-08-22 05:21:01.264163: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 938/938 [==============================] - 7s 7ms/step - loss: 3.1219 - sparse_categorical_accuracy: 0.8804
# Epoch 2/10
# 938/938 [==============================] - 6s 7ms/step - loss: 0.5380 - sparse_categorical_accuracy: 0.9297
# Epoch 3/10
# 938/938 [==============================] - 6s 7ms/step - loss: 0.3849 - sparse_categorical_accuracy: 0.9467
# Epoch 4/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.3222 - sparse_categorical_accuracy: 0.9556
# Epoch 5/10
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2837 - sparse_categorical_accuracy: 0.9616
# Epoch 6/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2653 - sparse_categorical_accuracy: 0.9656
# Epoch 7/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2549 - sparse_categorical_accuracy: 0.9676
# Epoch 8/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2308 - sparse_categorical_accuracy: 0.9704
# Epoch 9/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2248 - sparse_categorical_accuracy: 0.9715
# Epoch 10/10
# 938/938 [==============================] - 6s 6ms/step - loss: 0.2095 - sparse_categorical_accuracy: 0.9740

# %%
model.evaluate(test_dataset)
# Out:
#  33/157 [=====>........................] - ETA: 0s - loss: 0.9483 - sparse_categorical_accuracy: 0.9484
# 2021-08-22 05:23:08.969500: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 157/157 [==============================] - 1s 5ms/step - loss: 0.7794 - sparse_categorical_accuracy: 0.9569
# [0.779369056224823, 0.9569000601768494]
